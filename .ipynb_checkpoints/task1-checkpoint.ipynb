# %% [markdown]
# <p style="font-size:30px; text-align:center; line-height:120%">
#     <br>
#         <b>
#         COMS 4995 Applied ML
#             Homework 4
#         <br></br>
#             Wine Reviews: Task 1
#         <br></br>
#         </b>
#     <br>
# </p>
# <p style="font-size:18px; text-align:left; line-height:120%">
#     <br>
#         <b>
#         Name: Kirit Dhillon, Sagar Lal
#         </b>
#     <br>
#         <b>
#         Uni: ksd2142, sl3946
#         </b>
# </p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Data Loanding and Exploration

# %%
data = pd.read_csv("winemag-data-130k-v2.csv")

# Remove non-usefule columns
data = data.drop(['taster_name', 'taster_twitter_handle'], axis=1)

# %%
print(data.dtypes)
print(data.shape)
# Out:
# Unnamed: 0       int64
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# title           object
# variety         object
# winery          object
# dtype: object
# (129971, 12)

# %% [markdown]
# ### Setup Data

# %%
from sklearn.model_selection import train_test_split

#Split before deciding between text and non-text data to allow for joining later
X_trainval, X_test, y_trainval, y_test = train_test_split(data.drop(['points'], axis=1), data['points'])

# %%
text_X_trainval = X_trainval['description']
text_X_test = X_test['description']

non_text_X_trainval = X_trainval.drop(['description'], axis=1).reset_index().drop(['index', 'Unnamed: 0'], axis=1)
non_text_X_test = X_test.drop(['description'], axis=1).reset_index().drop(['index', 'Unnamed: 0'], axis=1)

# %%
print(text_X_trainval.shape, y_trainval.shape)
print(text_X_test.shape, y_test.shape)
print(non_text_X_trainval.shape)
print(non_text_X_test.shape)
# Out:
# (97478,) (97478,)
# (32493,) (32493,)
# (97478, 9)
# (32493, 9)

# %% [markdown]
# ## 1.1: Baseline model using non-text features

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Ridge
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
nt_continuous_features = ['price']
nt_categorical_features = ['country', 'title', 'designation', 'province', 'region_1', 'region_2',
                        'variety', 'winery']

# %%
base_categorical_transformer = Pipeline(steps=[('simpleimputer', SimpleImputer(strategy = 'constant', fill_value = "missing")),
                                          ('onehot', OneHotEncoder(handle_unknown='ignore'))])

base_continuous_transformer = Pipeline(steps=[('simpleimputer', SimpleImputer(strategy = "median")),
                                         ('scaler', StandardScaler())])

base_continuous_and_categorical_preprocessor = ColumnTransformer(
    transformers=[
        ('num', base_continuous_transformer, nt_continuous_features),
        ('cat', base_categorical_transformer, nt_categorical_features)
    ])

# %%
# %%time
# Baseline Ridge
base_ridge_clf = Pipeline(steps=[('preprocessor', base_continuous_and_categorical_preprocessor),
                                 ('classifier', Ridge())])

base_ridge_scores = cross_val_score(base_ridge_clf, non_text_X_trainval, y_trainval, cv=5)

print("Baseline Ridge with only CV: ", np.mean(base_ridge_scores))
# Out:
# Baseline Ridge with only CV:  0.5051966649020921
# CPU times: user 31.7 s, sys: 6.38 s, total: 38.1 s
# Wall time: 16.7 s

# %%
# %%time
ridge_pipeline = Pipeline(steps=[('preprocessor', base_continuous_and_categorical_preprocessor),
                                ('regressor', Ridge())])

param_grid =  {
               'regressor__alpha': [0.01, 0.1, 1, 10, 100]
              }
grid = GridSearchCV(ridge_pipeline, param_grid, cv=5, return_train_score=True)
grid.fit(non_text_X_trainval, y_trainval)

print(("Baseline Ridge score with GridSearchCV %.2f"
       # %grid.score(non_text_X_test, y_test)))
print("Best param:", grid.best_params_)
# Out:
# Baseline Ridge score with GridSearchCV 0.53
# Best param: {'regressor__alpha': 1}
# CPU times: user 5min 12s, sys: 1min 14s, total: 6min 26s
# Wall time: 3min 27s

# %% [markdown]
# ## 1.2: Text-based model based on:
# - Bag-of-Words
# - Linear Model

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_vect = CountVectorizer(stop_words="english", max_features=1000)

X_trainval_bow = bow_vect.fit_transform(text_X_trainval)
X_test_bow = bow_vect.transform(text_X_test)

# %%
print(X_trainval_bow.shape)
print(X_test_bow.shape)
# Out:
# (97478, 1000)
# (32493, 1000)

# %%
# %%time
ridge_pipeline = Pipeline(steps=[('regressor', Ridge())])

param_grid =  {
               'regressor__alpha': [0.01, 0.1, 1, 10, 100]
              }
grid = GridSearchCV(ridge_pipeline, param_grid, cv=3, return_train_score=True)
grid.fit(X_trainval_bow, y_trainval)

print(("Text-based Rigde score with GridSearchCV %.2f"
       # %grid.score(X_test_bow, y_test)))
print("Best param:", grid.best_params_)
# Out:
# Text-based Rigde score with GridSearchCV 0.61
# Best param: {'regressor__alpha': 10}
# CPU times: user 4.1 s, sys: 381 ms, total: 4.48 s
# Wall time: 4.63 s

# %% [markdown]
# ## 1.3: More text-based models:
# - Explore bigram/unigram models with stemming and removing stopwords
# - Expand on that model with using tf-idf

# %%
#Stemming function found: http://jonathansoma.com/lede/algorithms-2017/classes/more-text-analysis/counting-and-stemming/?fbclid=IwAR12cl7yIbpr-TXlS5IGukULm9kR30v_jocnRHAH5efFAECwTLlI7mt_yDw
from textblob import TextBlob

# Use TextBlob
def textblob_tokenizer(str_input):
    blob = TextBlob(str_input.lower())
    tokens = blob.words
    words = [token.stem() for token in tokens]
    return words

# %%
# %%time
import warnings
warnings.filterwarnings('ignore')
#unigram/bigram with stemming


bigram_vect = CountVectorizer(stop_words = 'english', tokenizer = textblob_tokenizer, 
                              ngram_range=(1, 2), max_features = 15000) 

X_trainval_bigram = bigram_vect.fit_transform(text_X_trainval)
X_test_bigram = bigram_vect.transform(text_X_test)

ridge_pipeline = Pipeline(steps=[('regressor', Ridge())])

param_grid =  {
               'regressor__alpha': [0.01, 0.1, 1, 10, 100]
              }
grid = GridSearchCV(ridge_pipeline, param_grid, cv=3, return_train_score=True)
grid.fit(X_trainval_bigram, y_trainval)

print(("Text-based Rigde score with GridSearchCV %.2f"
       # %grid.score(X_test_bigram, y_test)))
print("Best param:", grid.best_params_)
# Out:
# Text-based Rigde score with GridSearchCV 0.69
# Best param: {'regressor__alpha': 100}
# CPU times: user 5min 28s, sys: 15.5 s, total: 5min 43s
# Wall time: 5min 35s

# %%
print(bigram_vect.vocabulary_)
# Out:
416, 'pair': 9519, 'thi medium-bodi': 13306, 'medium-bodi wine': 8326, 'ha earthi': 6641, 'aroma good': 1282, 'good acid': 6299, 'flavor fresh': 5276, 'fresh mouthfeel': 5751, 'charact suggest': 2730, 'good pair': 6329, 'rich': 10836, 'preserv': 10336, 'raspberri': 10575, 'sauc': 11306, 'bean': 1675, 'low': 8078, 'leav': 7628, 'round': 11171, 'soft': 11793, 'impress': 7153, 'thi wine': 13476, 'wine rich': 14702, 'rich aroma': 10842, 'aroma flavor': 1270, 'flavor blackberri': 5192, 'blackberri preserv': 1993, 'ripe cherri': 11001, 'cherri raspberri': 2852, 'raspberri sauc': 10610, 'vanilla bean': 13954, 'low acid': 8079, 'acid leav': 657, 'round soft': 11196, 'impress palat': 7157, 'palat drink': 9585, 'small': 11680, 'parcel': 9727, 'soil': 11875, 'estat': 4672, 'wood-ag': 14826, 'toast': 13587, 'herbal': 6890, 'apricot': 1166, 'quinc': 10527, 'fruiti': 6075, 'edg': 4494, 'promis': 10409, 'age': 809, 'small parcel': 11683, 'estat thi': 4677, 'thi ripe': 13377, ' ...

# %%
# %%time
#tf_idf with unigram/bigram with stop words and stemming
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
bigram_tfidf = make_pipeline(bigram_vect,
                             TfidfTransformer(),
                            )

X_trainval_bigram_tfidf = bigram_tfidf.fit_transform(text_X_trainval)

X_test_bigram_tfidf = bigram_tfidf.transform(text_X_test)

ridge_pipeline = Pipeline(steps=[('regressor', Ridge())])

param_grid =  {
               'regressor__alpha': [0.01, 0.1, 1, 10, 100]
              }
grid = GridSearchCV(ridge_pipeline, param_grid, cv=3, return_train_score=True)
grid.fit(X_trainval_bigram_tfidf, y_trainval)

print(("Text-based Rigde score with GridSearchCV %.2f"
       # %grid.score(X_test_bigram_tfidf, y_test)))
print("Best param:", grid.best_params_)
# Out:
# Text-based Rigde score with GridSearchCV 0.69
# Best param: {'regressor__alpha': 1}
# CPU times: user 5min 34s, sys: 9.99 s, total: 5min 44s
# Wall time: 6min 20s

# %% [markdown]
# ## 1.4: Text and non-text features hybrid model

# %%
#Convert sparse matrix to df
X_trainval_bigram_tfidf = pd.DataFrame(X_trainval_bigram_tfidf.toarray())

# %%
#Merge non-text and BOW and test
full_X_trainval = pd.concat([non_text_X_trainval, X_trainval_bigram_tfidf], axis=1)

# %%
#Feed through column transformer and ridge pipeline

full_X_trainval
# Out:
#             country                                 designation  price  \
# 0                US                                         NaN   50.0
# 1      South Africa          Made With Organically Grown Grapes   10.0
# 2             Italy                         Vigneto San Martino    NaN
# 3          Portugal                                     Pomares   15.0
# 4             Italy                                         NaN   65.0
# 5                US                                     Unoaked   34.0
# 6      South Africa                                    The Coco    NaN
# 7            France                         Grand Vin Blanc Sec   39.0
# 8         Argentina                                    Elevated   13.0
# 9                US          The Nuts Sawyer Lindquist Vineyard   74.0
# 10           France                            Domaine Guenault   15.0
# 11            Italy                                    Lu Patri   46.0
# 12           France                                         NaN   18.0
# 13            Italy                                  Contrada R   60.0
# 14            Chile                                     Reserva    9.0
# 15               US  Tinaquaic Vineyard Estate Grown Dry Farmed   37.0
# 16               US               Reserve Zephyr Ridge Vineyard   30.0
# 17         Portugal                             Vinha das Romãs   40.0
# 18          Austria                             Austrian Pepper   15.0
# 19            Italy                                   Anagallis   42.0
# 20            Italy                                         NaN   19.0
# 21               US         Vintner's Pride Estate Grown Encore    NaN
# 22            Spain                                 Amontillado   15.0
# 23            Italy                                       STLTO   10.0
# 24           France                                  Les Roches   22.0
# 25               US                               Fatalis Fatum   37.0
# 26         Portugal                                 Loios Tinto   10.0
# 27          Austria                                   Hohenberg   24.0
# 28            Italy            Sergio Zingarelli Gran Selezione  130.0
# 29            Chile                       Barrel Select Reserve   12.0
# ...             ...                                         ...    ...
# 97448        France                               Petit Guiraud    NaN
# 97449        France             Château La Sauvageonne Volcanic   25.0
# 97450         Chile                                         NaN   14.0
# 97451         Italy                                   Le Muraie   19.0
# 97452            US                                         NaN   18.0
# 97453            US                                  Revelation   40.0
# 97454        France                                  Côte du Py   25.0
# 97455         Chile                                         NaN    9.0
# 97456            US                       Staten Family Reserve   35.0
# 97457            US                               Redwood Ranch   25.0
# 97458      Slovenia                                       Yanez   18.0
# 97459         Chile                             Puerto Viejo PV   12.0
# 97460            US                     Olsen Vineyard Ma Belle   45.0
# 97461            US                          Rosella's Vineyard   40.0
# 97462         Spain                                       Prima   25.0
# 97463        France                Aux Serpentières Premier Cru   65.0
# 97464         Spain                                  Particular   10.0
# 97465         Italy                                   Roccanera   16.0
# 97466            US                                Estate Grown   36.0
# 97467        France                      Château Lauduc Classic   15.0
# 97468            US                                         NaN   10.0
# 97469            US                                      Estate   60.0
# 97470         Italy                                   Borgonero   20.0
# 97471         Spain                                     Reserva   40.0
# 97472            US                                         NaN   45.0
# 97473            US                                         NaN   25.0
# 97474            US                                   The Gnome   18.0
# 97475         Spain                           Selección Reserva   21.0
# 97476         Spain                                     Reserva   27.0
# 97477        France                        La Marinière Sur Lie    9.0
#
#                    province                                 region_1  \
# 0                California                        Santa Ynez Valley
# 1              Western Cape                                      NaN
# 2                  Lombardy                                   Lugana
# 3                     Douro                                      NaN
# 4                   Tuscany                   Brunello di Montalcino
# 5                California                               California
# 6              Western Cape                                      NaN
# 7                  Bordeaux                           Bordeaux Blanc
# 8          Mendoza Province                               Uco Valley
# 9                California                              Edna Valley
# 10             Loire Valley                                 Touraine
# 11        Sicily & Sardinia                                  Sicilia
# 12                 Bordeaux                           Bordeaux Blanc
# 13        Sicily & Sardinia                          Terre Siciliane
# 14             Maipo Valley                                      NaN
# 15               California                       Santa Maria Valley
# 16               Washington                       Horse Heaven Hills
# 17               Alentejano                                      NaN
# 18         Niederösterreich                                      NaN
# 19                  Tuscany             Colli della Toscana Centrale
# 20                  Tuscany                      Rosso di Montalcino
# 21                 New York                North Fork of Long Island
# 22                Andalucia                                    Jerez
# 23            Central Italy                          Terre di Chieti
# 24               Beaujolais                                  Fleurie
# 25                 New York                              Long Island
# 26               Alentejano                                      NaN
# 27         Wagram-Donauland                                      NaN
# 28                  Tuscany                         Chianti Classico
# 29         Cachapoal Valley                                      NaN
# ...                     ...                                      ...
